# %%
import pandas as pd
import random as rdm
pd.set_option('display.max_columns', None)

# %%
pl = pd.read_csv("NBA 2021 Per 100.csv", header = 4)
pl = pl.drop(columns = ['Unnamed: 22'])
#pl

# %%
gp = pl.loc[pl['Better'] == 1].copy()
#gp

# %%
bp = pl.loc[pl['Better'] == 0].copy()
#bp

# %%
matchl = pd.DataFrame(columns = pl.columns)
for i in range(24):
    matchl = matchl.append(gp.sample(n=100), ignore_index=True).copy()
#matchl

# %%
matchr = pd.DataFrame(columns = pl.columns)
for i in range(6):
    matchr = matchr.append(bp.sample(n=400), ignore_index=True).copy()
#matchr

# %%
for i in range(len(matchl.index)):
    coin = rdm.randint(0,1)
    if coin == 1:
        temp1, temp2 = matchl.iloc[i].copy(), matchr.iloc[i].copy()
        matchl.iloc[i], matchr.iloc[i] = temp2, temp1
matchl = matchl.drop(columns = ['Better'])

# %%
matchup = pd.concat([matchl, matchr], axis = 1).copy()
matchup = matchup.drop_duplicates(ignore_index = True)
pd.set_option('display.max_columns', None)
#matchup

# %%
#data = matchup.drop(columns = ['Player']).copy()
#%store matchup2
#matchup2

# %%
data = matchup.drop(columns = ['Player','Better','ORtg','DRtg']).copy()
label = matchup['Better'].copy()

# %%
datan = data.copy()
datan['Pos'] = datan['Pos'].replace({'PG':0, 'PG-SG':0.125, 'SG-PG':0.125, 'SG':0.25, 'SG-SF':0.375, 'SF-SG':0.375, 'SF':0.5, 
                                       'SF-PF':0.625, 'PF-SF':0.625, 'PF':0.75, 'PF-C':0.875, 'C-PF':0.875, 'C':1})
#tdatan.iloc[:, [0]] = tdatan.iloc[:, [0]]/tdatan.iloc[:, [0]].max()
#tdatan.iloc[:, [0]]
for i in datan.columns:
    #if tdatan[i].max() == 1 and tdatan[i].min() == 0:
    datan[i] = (datan[i] - datan[i].min())/datan[i].max()
#datan['ORtg'] = (datan['ORtg'] - datan['ORtg'].min())/(datan['ORtg'].max() - datan['ORtg'].min())
#pd.set_option('display.max_rows', None)
datan
# Out:
#         Pos       Age         G        GS        MP        FG       FGA  \
# 0     0.875  0.142857  0.746479  0.152778  0.295796  0.277946  0.377465
# 1     0.250  0.428571  0.971831  0.430556  0.743994  0.305136  0.636620
# 2     0.500  0.380952  0.309859  0.027778  0.137387  0.166163  0.363380
# 3     0.250  0.142857  0.267606  0.069444  0.194069  0.214502  0.492958
# 4     1.000  0.761905  0.957746  0.083333  0.447823  0.217523  0.343662
# ...     ...       ...       ...       ...       ...       ...       ...
# 2374  0.500  0.476190  0.943662  0.944444  0.850601  0.320242  0.625352
# 2375  0.000  0.333333  0.042254  0.013889  0.028529  0.166163  0.416901
# 2375  1.000  0.333333  0.704225  0.708333  0.593844  0.422961  0.771831
# 2376  0.250  0.476190  0.802817  0.250000  0.489489  0.190332  0.343662
# 2377  0.750  0.476190  0.985915  0.222222  0.566817  0.105740  0.273239
# 2378  0.750  0.333333  0.985915  0.986111  1.000000  0.341390  0.698592
#
#             3P       3PA        2P       2PA        FT       FTA       ORB  \
# 0     0.702703  0.731429  0.217523  0.425982  0.230769  0.245509  0.093750
# 1     0.418919  0.514286  0.154079  0.241692  0.244755  0.257485  0.218750
# 2     0.364865  0.400000  0.226586  0.401813  0.181818  0.197605  0.187500
# 3     0.459459  0.600000  0.208459  0.447130  0.321678  0.365269  0.052083
# 4     0.391892  0.520000  0.238671  0.528701  0.405594  0.467066  0.062500
# ...        ...       ...       ...       ...       ...       ...       ...
# 2374  0.000000  0.005714  0.132931  0.214502  0.111888  0.137725  0.479167
# 2375  0.243243  0.268571  0.371601  0.685801  1.000000  1.000000  0.354167
# 2376  0.216216  0.251429  0.141994  0.235650  0.174825  0.173653  0.114583
# 2377  0.297297  0.394286  0.039275  0.084592  0.076923  0.089820  0.145833
# 2378  0.405405  0.417143  0.250755  0.528701  0.454545  0.479042  0.166667
#
#            DRB       AST       STL       BLK       TOV       PF       PTS
# 0     0.264045  0.456376  0.185714  0.074074  0.052083  0.16875  0.500000
# 1     0.550562  0.328859  0.271429  0.123457  0.080729  0.31250  0.347432
# 2     0.269663  0.590604  0.342857  0.111111  0.080729  0.15000  0.389728
# 3     0.365169  0.442953  0.285714  0.074074  0.096354  0.22500  0.433535
# 4     0.230337  0.677852  0.214286  0.135802  0.135417  0.10625  0.456193
# ...        ...       ...       ...       ...       ...      ...       ...
# 2374  0.483146  0.100671  0.328571  0.567901  0.054688  0.35625  0.158610
# 2375  0.730337  0.295302  0.214286  0.259259  0.125000  0.23125  0.666163
# 2376  0.235955  0.677852  0.214286  0.061728  0.093750  0.20625  0.250755
# 2377  0.314607  0.161074  0.228571  0.049383  0.036458  0.23750  0.155589
# 2378  0.674157  0.536913  0.171429  0.037037  0.117188  0.26250  0.484894
#
# [2379 rows x 42 columns]

# %%
label
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 2374    0.0
# 2375    1.0
# 2376    0.0
# 2377    0.0
# 2378    1.0
# Name: Better, Length: 2379, dtype: float64

# %%
train_datan = datan[:2000].copy()
test_datan = datan[2000:].copy()
train_label = label[:2000].copy()
test_label = label[2000:].copy()
# %store train_datan test_datan train_label test_label
# Out:
# Stored 'train_datan' (DataFrame)
# Stored 'test_datan' (DataFrame)
# Stored 'train_label' (Series)
# Stored 'test_label' (Series)
